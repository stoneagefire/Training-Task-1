# %%
import pandas as pd
import numpy as np

# %%
user_detial_csv = pd.read_csv('user_email_hash.1m.tsv', sep='\t')
plain_csv = pd.read_csv('plain_32m.tsv', sep='\t')

# %%
ip_csv = pd.read_csv('ip_1m.tsv', sep='\t')
# Out:
# C:\Users\patel\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ip_csv.head(10)
# Out:
#    id      ip_address
# 0   1   76.254.72.182
# 1  14     75.24.93.28
# 2  24    24.23.203.76
# 3  26  24.177.135.117
# 4  28   68.120.195.44
# 5  29  151.151.21.100
# 6  31   68.127.28.140
# 7  35     99.35.224.8
# 8  47  151.151.73.171
# 9  52     24.63.70.20

# %%
user_detial_csv.head(10)
# Out:
#    id       username                       email  \
# 0   1      wisehight         mikeslee2@gmail.com
# 1  14  witchbefooled       amy_bricker@yahoo.com
# 2  24      LIBERTINE        albertslee@yahoo.com
# 3  26         Donald     tester@myfitnesspal.com
# 4  28         suffer  mikeslee+testmfp@gmail.com
# 5  29         manure         steveyung@gmail.com
# 6  31         krikit        lindacchou@gmail.com
# 7  35     convolvuli           schow@hotmail.com
# 8  47     Pritchards         julie.yim@gmail.com
# 9  52          sager    franbanan123@hotmail.com
#
#                                    password
# 0  12e89f289a1a17819c38212adefe85fd8bcf9650
# 1  0d4a4c56014de2586b07b82323cc91574bb889ec
# 2  1096f253a9f6d31b884459ae6c5d4ec611681fd5
# 3  28a52af092225ca458d853e43114d43a94ea00b7
# 4  1289882820f4acddbb624e6df3a9383dadb1eca9
# 5  cfd21637f6bbc52d71da97125d0e3fe9d7eeea1c
# 6  55303ccd70288c624de14adc954777511990b918
# 7  fce5de9bd3c2a9e94e0cd796047bb011315511a2
# ...

# %%
plain_csv = plain_csv.sort_values(ascending=True, by='email')

# %%
user_email = user_detial_csv['email'].sort_values(ascending=True)
username = user_detial_csv['username']
user_id = user_detial_csv['id']
plain_email = plain_csv['email']
plain_pass = plain_csv['plain']

# %%
plain_pass.head(10)
# Out:
# 7251          Prouf
# 11876        aprils
# 4590         Dunlip
# 8665       Wombwell
# 5724       monomyth
# 3473       Shan-don
# 2474       beggered
# 4560        blueild
# 16447    flyswatter
# 16355    Newsletter
# Name: plain, dtype: object

# %%
plain_email.head(10)
# Out:
# 7251                     003168@live.com.au
# 11876                 01eviibabee@gmail.com
# 4590                 027mrdavis03@gmail.com
# 8665                      03.1416@gmail.com
# 5724                05davisfamily@gmail.com
# 3473                     064118r@acadiau.ca
# 2474                 0794459@student.hro.nl
# 4560      08jcantlie-king@chaileyschool.org
# 16447    08shannon.taylor@northfieldssc.net
# 16355              0n-the-clouds@hotmail.ca
# Name: email, dtype: object

# %%
user_email.head(10)
# Out:
# 485843               #@wonkybadger.net
# 540444    **btpaulson@milfordcable.net
# 674755     --gemma-louise--@live.co.uk
# 664863          -pleasure_@hanmail.net
# 34286                    00-00@live.ca
# 524347               0001@daltilia.com
# 804242               000annie@live.com
# 353504                006mlb@gmail.com
# 683670              007Morse@gmail.com
# 390812           007lipgloss@gmail.com
# Name: email, dtype: object

# %%
user_ip_ip = ip_csv['ip_address']
user_ip_id = ip_csv['id']
print(type(user_ip_id[0]))
# Out:
# <class 'str'>

# %%
temp_list_ip = []
for i in range(len(user_id)):
    if user_id[1]==np.int64(user_ip_id[1]):
        temp_list_ip.append([user_id[i], user_ip_ip[i]])

print(temp_list_ip[:10])
# Out:
# [[1, '76.254.72.182'], [14, '75.24.93.28'], [24, '24.23.203.76'], [26, '24.177.135.117'], [28, '68.120.195.44'], [29, '151.151.21.100'], [31, '68.127.28.140'], [35, '99.35.224.8'], [47, '151.151.73.171'], [52, '24.63.70.20']]

# %% [markdown]
# Segmenting Series into alphabetic order.

# %%
listchr = []
lista = []
listb = []
listc = []
listd = []
liste = []
listf = []
listg = []
listh = []
listi = []
listj = []
listk = []
listl = []
listm = []
listn = []
listo = []
listp = []
listq = []
listr = []
lists = []
listt = []
listu = []
listv = []
listw = []
listx = []
listy = []
listz = []

# %%
list_chr = []
list_a = []
list_b = []
list_c = []
list_d = []
list_e = []
list_f = []
list_g = []
list_h = []
list_i = []
list_j = []
list_k = []
list_l = []
list_m = []
list_n = []
list_o = []
list_p = []
list_q = []
list_r = []
list_s = []
list_t = []
list_u = []
list_v = []
list_w = []
list_x = []
list_y = []
list_z = []

# %%
for i in user_email:
    if i[0]=='a':
        lista.append(i)
    elif i[0]=='b':
        listb.append(i)
    elif i[0]=='c':
        listc.append(i)
    elif i[0]=='d':
        listd.append(i)
    elif i[0]=='e':
        liste.append(i)
    elif i[0]=='f':
        listf.append(i)
    elif i[0]=='g':
        listg.append(i)
    elif i[0]=='h':
        listh.append(i)
    elif i[0]=='i':
        listi.append(i)
    elif i[0]=='j':
        listj.append(i)
    elif i[0]=='k':
        listk.append(i)
    elif i[0]=='l':
        listl.append(i)
    elif i[0]=='m':
        listm.append(i)
    elif i[0]=='n':
        listn.append(i)
    elif i[0]=='o':
        listo.append(i)
    elif i[0]=='p':
        listp.append(i)
    elif i[0]=='q':
        listq.append(i)
    elif i[0]=='r':
        listr.append(i)
    elif i[0]=='s':
        lists.append(i)
    elif i[0]=='t':
        listt.append(i)
    elif i[0]=='u':
        listu.append(i)
    elif i[0]=='v':
        listv.append(i)
    elif i[0]=='w':
        listw.append(i)
    elif i[0]=='x':
        listx.append(i)
    elif i[0]=='y':
        listy.append(i)
    elif i[0]=='z':
        listz.append(i)
    else:
        listchr.append(i)

# %%
for i in plain_email:
    if i[0]=='a':
        list_a.append(i)
    elif i[0]=='b':
        list_b.append(i)
    elif i[0]=='c':
        list_c.append(i)
    elif i[0]=='d':
        list_d.append(i)
    elif i[0]=='e':
        list_e.append(i)
    elif i[0]=='f':
        list_f.append(i)
    elif i[0]=='g':
        list_g.append(i)
    elif i[0]=='h':
        list_h.append(i)
    elif i[0]=='i':
        list_i.append(i)
    elif i[0]=='j':
        list_j.append(i)
    elif i[0]=='k':
        list_k.append(i)
    elif i[0]=='l':
        list_l.append(i)
    elif i[0]=='m':
        list_m.append(i)
    elif i[0]=='n':
        list_n.append(i)
    elif i[0]=='o':
        list_o.append(i)
    elif i[0]=='p':
        list_p.append(i)
    elif i[0]=='q':
        list_q.append(i)
    elif i[0]=='r':
        list_r.append(i)
    elif i[0]=='s':
        list_s.append(i)
    elif i[0]=='t':
        list_t.append(i)
    elif i[0]=='u':
        list_u.append(i)
    elif i[0]=='v':
        list_v.append(i)
    elif i[0]=='w':
        list_w.append(i)
    elif i[0]=='x':
        list_x.append(i)
    elif i[0]=='y':
        list_y.append(i)
    elif i[0]=='z':
        list_z.append(i)
    else:
        list_chr.append(i)

# %%
new_temp_list1 = [
    listchr, lista, listb, listc, 
    listd, liste, listf, listg, 
    listh, listi, listj, listk, 
    listl, listm, listn, listo, 
    listp, listp, listq, listr, 
    lists, listt, listu, listv, 
    listw, listx, listy, listz
]

new_temp_list2 = [
    list_chr, list_a, list_b, list_c, 
    list_d, list_e, list_f, list_g, 
    list_h, list_i, list_j, list_k, 
    list_l, list_m, list_n, list_o, 
    list_p, list_p, list_q, list_r, 
    list_s, list_t, list_u, list_v, 
    list_w, list_x, list_y, list_z
]

# %%
temp_list1 = []
temp_list2 = []

for i in listchr:
    for j in list_chr:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
            break
temp_list2.append(temp_list1)

temp_list1 = []
for i in lista:
    for j in list_a:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
            break
temp_list2.append(temp_list1)

temp_list1 = []
for i in listb:
    for j in list_b:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listc:
    for j in list_c:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listd:
    for j in list_d:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in liste:
    for j in list_e:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listf:
    for j in list_f:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listg:
    for j in list_g:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listh:
    for j in list_h:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listi:
    for j in list_i:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listj:
    for j in list_j:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listk:
    for j in list_k:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listl:
    for j in list_l:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listm:
    for j in list_m:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listn:
    for j in list_n:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listo:
    for j in list_o:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listp:
    for j in list_p:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listq:
    for j in list_q:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listr:
    for j in list_r:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in lists:
    for j in list_s:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listt:
    for j in list_t:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listu:
    for j in list_u:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listv:
    for j in list_v:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listw:
    for j in list_w:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listx:
    for j in list_x:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listy:
    for j in list_y:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

temp_list1 = []
for i in listz:
    for j in list_z:
        if i==j:
            indexvalue = plain_csv[plain_csv['email'] == i].index
            temp_list1.append(indexvalue[0])
temp_list2.append(temp_list1)

# %%
hased_pass = user_detial_csv['password']
hased_pass.head(5)
# Out:
# 0    12e89f289a1a17819c38212adefe85fd8bcf9650
# 1    0d4a4c56014de2586b07b82323cc91574bb889ec
# 2    1096f253a9f6d31b884459ae6c5d4ec611681fd5
# 3    28a52af092225ca458d853e43114d43a94ea00b7
# 4    1289882820f4acddbb624e6df3a9383dadb1eca9
# Name: password, dtype: object

# %%
final_list = []
for i in temp_list2:
    for j in i:
        val = 0
        for k in temp_list_ip:
            if k[0]==j:
                val = k[1]
        final_list.append([user_id[j], username[j], user_email[j], hased_pass[j], plain_pass[j], val])

# %%
import csv

# %%
with open('outfile.tsv', 'w+') as f:
    writer = csv.writer(f, delimiter='\t')
    for row in final_list:
        writer.writerow(row)
